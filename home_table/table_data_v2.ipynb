# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
DATA_PATH = '/Users/dafneculha/Desktop/project-2023-choo-choo-data-darlings/home_table/transports_v2.parquet'
transport_data = pd.read_parquet(DATA_PATH)

# %%
transport_df = pd.DataFrame(transport_data)

# %%
transport_df
# Out:
#                       trip_id product_id line_text transport_type  stop_id  \
# 0         80:06____:17171:000      Train        RB             RB  8500090
# 1         80:06____:17261:000      Train        RB             RB  8500090
# 2          80:800693:3053:000      Train      IRE3            IRE  8503424
# 4             80:sbg034:14004        Bus   Bus7349              B  8573327
# 6             80:sbg034:55413        Bus   Bus7349              B  8503474
# ...                       ...        ...       ...            ...      ...
# 65804932      85:97:26840:000      Train         R              R  8501112
# 65804933         85:97:41:000      Train         R              R  8504291
# 65804934         85:97:52:000      Train         R              R  8504294
# 65804935         85:97:60:000      Train         R              R  8504292
# 65804936         85:97:69:000      Train         R              R  8530263
#
#          arrival_time departure_time  mean_arrival_delay  \
# ...

# %%
transport_df = transport_df.drop_duplicates()
## nothing changes so it's good

# %%
transport_df
# Out:
#                       trip_id product_id line_text transport_type  stop_id  \
# 0         80:06____:17171:000      Train        RB             RB  8500090
# 1         80:06____:17261:000      Train        RB             RB  8500090
# 2          80:800693:3053:000      Train      IRE3            IRE  8503424
# 4             80:sbg034:14004        Bus   Bus7349              B  8573327
# 6             80:sbg034:55413        Bus   Bus7349              B  8503474
# ...                       ...        ...       ...            ...      ...
# 65804932      85:97:26840:000      Train         R              R  8501112
# 65804933         85:97:41:000      Train         R              R  8504291
# 65804934         85:97:52:000      Train         R              R  8504294
# 65804935         85:97:60:000      Train         R              R  8504292
# 65804936         85:97:69:000      Train         R              R  8530263
#
#          arrival_time departure_time  mean_arrival_delay  \
# ...

# %%
agg_dict = {'mean_arrival_delay': 'mean',
            'mean_departure_delay': 'mean',
            'median_arrival_delay': 'median',
            'median_departure_delay': 'median',
            'std_arrival_delay': 'std',
            'std_departure_delay': 'std',
            'n_arrival_delay': 'sum',
            'n_departure_delay': 'sum',
            'n_cancelled': 'sum',
            'n_through_trip': 'sum',
            'n_additional_trip': 'sum',
            'n_entries': 'sum'}

# %%
grouped_df = transport_df.groupby('stop_id').agg(agg_dict)

# %%
grouped_df
# Out:
#          mean_arrival_delay  mean_departure_delay  median_arrival_delay  \
# stop_id
# 8500010          126.933136            113.651929                  39.0
# 8500016          112.264273            135.597730                  52.0
# 8500020           88.235659            117.924160                  65.0
# 8500021           68.463766             92.650182                  43.0
# 8500022           95.764394            129.524718                  68.0
# ...                     ...                   ...                   ...
# 8596120          166.798959            168.425553                 147.0
# 8596121          147.709830            156.376282                 121.5
# 8596122           67.555925             86.427152                  71.0
# 8596123           44.700022             55.023609                  19.5
# 8596125          202.011619            204.411319                 183.5
#
#          median_departure_delay  std_arrival_delay  std_departure_delay  \
# stop_id
# ...

# %%
grouped_df.head()
# Out:
#          mean_arrival_delay  mean_departure_delay  median_arrival_delay  \
# stop_id
# 8500010          126.933136            113.651929                  39.0
# 8500016          112.264273            135.597730                  52.0
# 8500020           88.235659            117.924160                  65.0
# 8500021           68.463766             92.650182                  43.0
# 8500022           95.764394            129.524718                  68.0
#
#          median_departure_delay  std_arrival_delay  std_departure_delay  \
# stop_id
# 8500010                    49.0         303.710612           238.857298
# 8500016                    76.0         113.499117           113.914276
# 8500020                    95.0          36.591625            36.790550
# 8500021                    67.0          34.731840            35.081240
# 8500022                   102.0          39.203712            38.831981
#
#          n_arrival_delay  n_departure_delay  n_cancelled  n_through_trip  \
# ...

# %%
# Load the other df
df_names = pd.read_csv('/Users/dafneculha/Desktop/project-2023-choo-choo-data-darlings/data/processed/stops.csv', usecols=['stop_id', 'stop_name', 'city', 'canton'], index_col='stop_id')

# %%
df_names
# Out:
#                 stop_name       city canton
# stop_id
# 8500010         Basel SBB      Basel     BS
# 8500016  Basel St. Johann      Basel     BS
# 8500020           Muttenz    Muttenz     BL
# 8500021          Pratteln   Pratteln     BL
# 8500023           Liestal    Liestal     BL
# ...                   ...        ...    ...
# 8596080            Neuweg   Beringen     SH
# 8596106         Belvedere   Beringen     SH
# 8596102      Case à Chocs  Neuchâtel     NE
# 8596107         Oberstieg   Beringen     SH
# 8596108           Eggeweg   Beringen     SH
#
# [20012 rows x 3 columns]

# %%
merged_df = df_names.merge(grouped_df, on='stop_id')

# %%
merged_df.head()
# Out:
#                 stop_name      city canton  mean_arrival_delay  \
# stop_id
# 8500010         Basel SBB     Basel     BS          126.933136
# 8500016  Basel St. Johann     Basel     BS          112.264273
# 8500020           Muttenz   Muttenz     BL           88.235659
# 8500021          Pratteln  Pratteln     BL           68.463766
# 8500023           Liestal   Liestal     BL          111.112872
#
#          mean_departure_delay  median_arrival_delay  median_departure_delay  \
# stop_id
# 8500010            113.651929                  39.0                    49.0
# 8500016            135.597730                  52.0                    76.0
# 8500020            117.924160                  65.0                    95.0
# 8500021             92.650182                  43.0                    67.0
# 8500023            148.421658                  67.0                   104.0
#
#          std_arrival_delay  std_departure_delay  n_arrival_delay  \
# stop_id
# ...

# %%
df_tosave = merged_df.reset_index().to_json(orient='records')

#with open('table_df.json', 'w') as f:
#    f.write(df_tosave)

# %%
hist_values, bins, _ = plt.hist(merged_df['mean_arrival_delay'], bins=100)  # Adjust the number of bins as needed

plt.xlabel('Mean Arrival Delay')
plt.ylabel('Frequency')
plt.title('Histogram of Mean Arrival Delay')

histogram_settings = {
    'num_bins': len(bins) - 1,  # Number of bins
    'bin_size': (bins[1] - bins[0]).tolist(),  # Bin size
    'bins': bins.tolist(),  # Convert the bins array to a list
    'hist_values': hist_values.tolist()  # Convert the hist_values array to a list
}

with open('mean_arrival_delay.json', 'w') as f:
    json.dump(histogram_settings, f)

plt.show()

# %%
hist_values, bins, _ = plt.hist(merged_df['mean_departure_delay'], bins=100)  # Adjust the number of bins as needed

plt.xlabel('Mean Dep Delay')
plt.ylabel('Frequency')
plt.title('Histogram of Mean Dep Delay')

histogram_settings = {
    'num_bins': len(bins) - 1,  # Number of bins
    'bin_size': (bins[1] - bins[0]).tolist(),  # Bin size
    'bins': bins.tolist(),  # Convert the bins array to a list
    'hist_values': hist_values.tolist()  # Convert the hist_values array to a list
}

with open('mean_departure_delay.json', 'w') as f:
    json.dump(histogram_settings, f)

plt.show()

# %%
hist_values, bins, _ = plt.hist(merged_df['n_arrival_delay'], bins=100)  # Adjust the number of bins as needed

plt.xlabel('N Arrival Delay')
plt.ylabel('Frequency')
plt.title('Histogram of N Arrival Delay')

histogram_settings = {
    'num_bins': len(bins) - 1,  # Number of bins
    'bin_size': (bins[1] - bins[0]).tolist(),  # Bin size
    'bins': bins.tolist(),  # Convert the bins array to a list
    'hist_values': hist_values.tolist()  # Convert the hist_values array to a list
}

with open('n_arrival_delay.json', 'w') as f:
    json.dump(histogram_settings, f)

plt.show()

# %%
hist_values, bins, _ = plt.hist(merged_df['n_departure_delay'], bins=100)  # Adjust the number of bins as needed

plt.xlabel('N Departure Delay')
plt.ylabel('Frequency')
plt.title('Histogram of n_departure_delay')

histogram_settings = {
    'num_bins': len(bins) - 1,  # Number of bins
    'bin_size': (bins[1] - bins[0]).tolist(),  # Bin size
    'bins': bins.tolist(),  # Convert the bins array to a list
    'hist_values': hist_values.tolist()  # Convert the hist_values array to a list
}

with open('histogram_settings.json', 'w') as f:
    json.dump(histogram_settings, f)


plt.show()

# %%
hist_values, bins, _ = plt.hist(merged_df['n_cancelled'], bins=100)  # Adjust the number of bins as needed


plt.xlabel('N Cancelled')
plt.ylabel('Frequency')
plt.title('Histogram of N Cancelled')

histogram_settings = {
    'num_bins': len(bins) - 1,  # Number of bins
    'bin_size': (bins[1] - bins[0]).tolist(),  # Bin size
    'bins': bins.tolist(),  # Convert the bins array to a list
    'hist_values': hist_values.tolist()  # Convert the hist_values array to a list
}

with open('histogram_settings.json', 'w') as f:
    json.dump(histogram_settings, f)


plt.show()
