# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
TRANSPORT_DATA_V2_PATH = "../../data/processed/transports_v2.parquet"

transport_data = pd.read_parquet(TRANSPORT_DATA_V2_PATH)
transport_data.head()
# Out:
#                trip_id product_id line_text transport_type  stop_id  \
# 0  80:06____:17171:000      Train        RB             RB  8500090
# 1  80:06____:17261:000      Train        RB             RB  8500090
# 2   80:800693:3053:000      Train      IRE3            IRE  8503424
# 4      80:sbg034:14004        Bus   Bus7349              B  8573327
# 6      80:sbg034:55413        Bus   Bus7349              B  8503474
#
#   arrival_time departure_time  mean_arrival_delay  mean_departure_delay  \
# 0     14:50:00           None          293.939394                   NaN
# 1         None       15:53:00                 NaN             61.621622
# 2     11:58:00       12:00:00          151.539474            127.605263
# 4     09:07:00           None            2.400000                   NaN
# 6     00:19:00       00:20:00          138.000000             96.000000
#
#    median_arrival_delay  median_departure_delay  std_arrival_delay  \
# 0                 120.0                     NaN         388.229414
# 1                   NaN                     0.0                NaN
# 2                  41.0                    19.0         627.797068
# 4                   0.0                     NaN          29.443320
# 6                 180.0                   120.0         107.025910
#
#    std_departure_delay  n_arrival_delay  n_departure_delay  n_cancelled  \
# 0                  NaN               68                  0            4
# 1           129.218022                0                  9            1
# 2           622.499501               60                 73            2
# 4                  NaN                5                  0            0
# 6            84.852814               70                 68            0
#
#    n_through_trip  n_additional_trip  n_entries
# 0               0                  0        104
# 1               0                  0        104
# 2               0                  0         78
# 4               0                  0        100
# 6               0                  0        100

# %%
print(f"Number of entries: {transport_data.shape[0]}")
# Out:
# Number of entries: 5527916

# %%
def remove_duplicates_without_line_text(data):
    new_data = data.copy()
    new_data = new_data.drop_duplicates(subset=['trip_id', 'product_id', 'transport_type', 'stop_id', 'arrival_time', 'departure_time'], keep="first")
    return new_data

transport_data = remove_duplicates_without_line_text(transport_data)
print(f"Number of entries: {transport_data.shape[0]}")
# Out:
# Number of entries: 5526137

# %%
# Add time column to sort
transport_data['time'] = transport_data['arrival_time'].fillna(transport_data['departure_time'])

# %%
train_data = transport_data[transport_data['product_id'] == 'Train'].copy()
print(f"Train entries represent {train_data.shape[0] / transport_data.shape[0]:.2%} of the total entries.")
print(f"Number of entries: {train_data.shape[0]}")
# Out:
# Train entries represent 6.30% of the total entries.
# Number of entries: 348148

# %%
# Save the train data
TRAINS_DATA_V2_PATH = "../../data/processed/trains_v2.parquet"
train_data.to_parquet(TRAINS_DATA_V2_PATH)

# %%
train_data.sort_values(['trip_id', 'time']).head()
# Out:
#                       trip_id product_id line_text transport_type  stop_id  \
# 50014196  80:06____:17001:000      Train       RE7             RE  8500090
# 17108720  80:06____:17001:000      Train       RE7             RE  8500090
# 14475623  80:06____:17003:000      Train       RE7             RE  8500090
# 59228240  80:06____:17003:000      Train       RE7             RE  8500090
# 48698740  80:06____:17005:000      Train       RE7             RE  8500090
#
#          arrival_time departure_time  mean_arrival_delay  \
# 50014196     07:29:00           None          177.831325
# 17108720     08:29:00           None          182.608696
# 14475623     09:03:00           None          140.526316
# 59228240     10:03:00           None          196.438356
# 48698740     10:29:00           None          308.936170
#
#           mean_departure_delay  median_arrival_delay  median_departure_delay  \
# 50014196                   NaN                 120.0                     NaN
# 17108720                   NaN                  60.0                     NaN
# 14475623                   NaN                   0.0                     NaN
# 59228240                   NaN                  60.0                     NaN
# 48698740                   NaN                 120.0                     NaN
#
#           std_arrival_delay  std_departure_delay  n_arrival_delay  \
# 50014196         212.120813                  NaN               74
# 17108720         238.778229                  NaN              115
# 14475623         263.554648                  NaN               34
# 59228240         413.927763                  NaN               76
# 48698740         620.798078                  NaN               83
#
#           n_departure_delay  n_cancelled  n_through_trip  n_additional_trip  \
# 50014196                  0            3               0                  0
# 17108720                  0            4               0                  0
# 14475623                  0            3               0                  0
# 59228240                  0            2               1                  0
# 48698740                  0            2               0                  0
#
#           n_entries      time
# 50014196         86  07:29:00
# 17108720        142  08:29:00
# 14475623         79  09:03:00
# 59228240        148  10:03:00
# 48698740         96  10:29:00

# %%
def remove_single_stop_journeys(data):
    """
    Remove journeys that only have the same stop id in each of its entries.
    """
    new_data = data.copy()
    # Group by 'trip_id' and check if all 'stop_id' values are the same
    grouped_data = new_data.groupby('trip_id').agg({
        'stop_id': lambda x: len(x.unique()) == 1
    }).reset_index().rename(columns={'stop_id': 'single_stop'})

    # Merge the grouped_data with the original DataFrame
    data_with_single_stop = new_data.merge(grouped_data, on='trip_id')

    # Filter out the rows with single_stop == True
    filtered_data = data_with_single_stop[~data_with_single_stop['single_stop']].drop(columns=['single_stop'])

    return filtered_data

train_data = remove_single_stop_journeys(train_data)
print(f"Number of entries: {train_data.shape[0]}")
train_data.sort_values(['trip_id', 'time']).head()
# Out:
# Number of entries: 5524471
#                     trip_id product_id line_text transport_type  stop_id  \
# 5517226  80:800693:3040:000      Train      IRE3            IRE  8503424
# 5517228  80:800693:3040:000      Train      IRE3            IRE  8503424
# 5517225  80:800693:3040:000      Train      IRE3            IRE  8500090
# 5517227  80:800693:3040:000      Train      IRE3            IRE  8500090
# 5203290  80:800693:3041:000      Train        RB             RB  8500090
#
#         arrival_time departure_time  mean_arrival_delay  mean_departure_delay  \
# 5517226     06:58:00       07:00:00          307.000000            252.146667
# 5517228     07:58:00       08:00:00          158.090278            114.597222
# 5517225     08:15:00           None          126.575342                   NaN
# 5517227     09:15:00           None           63.750000                   NaN
# 5203290         None       05:58:00                 NaN                   NaN
#
#          median_arrival_delay  median_departure_delay  std_arrival_delay  \
# 5517226                 101.0                    39.0         644.312728
# 5517228                  92.0                    38.0         356.211415
# 5517225                   0.0                     NaN         437.328440
# 5517227                   0.0                     NaN         341.497883
# 5203290                   NaN                     NaN                NaN
#
#          std_departure_delay  n_arrival_delay  n_departure_delay  n_cancelled  \
# 5517226           638.846885               75                 75            1
# 5517228           351.588390              142                144            4
# 5517225                  NaN               17                  0            2
# 5517227                  NaN               22                  0            4
# 5203290                  NaN                0                  0            2
#
#          n_through_trip  n_additional_trip  n_entries      time
# 5517226               0                  0         76  06:58:00
# 5517228               0                  0        148  07:58:00
# 5517225               0                  0         76  08:15:00
# 5517227               0                  0        148  09:15:00
# 5203290               0                  0         80  05:58:00

# %%
def enhance_trip_id(data):
    new_data = data.copy()

    # Sort data by trip_id, stop_id, and time
    new_data = new_data.sort_values(['trip_id', 'stop_id', 'time'])

    # Group data by trip_id and stop_id and assign an increasing number for each group
    new_data['group_number'] = new_data \
        .groupby(['trip_id', 'stop_id']) \
        .cumcount() + 1

    # Update the trip_id by appending the group_number
    new_data['trip_id'] = new_data['trip_id'].astype(str) + '_' + new_data['group_number'].astype(str)

    # Remove the group_number column
    new_data = new_data.drop(columns=['group_number'])

    return new_data

train_data = enhance_trip_id(train_data)
train_data.sort_values(['trip_id', 'time']).head()
print(f"Number of entries: {train_data.shape[0]}")
# Out:
# Number of entries: 5524471

# %%
def add_trip_index(data):
    new_data = data.copy()
    # Add a temporary unique identifier to the original data
    new_data['_temp_id'] = np.arange(len(data))
    
    trip_stops = new_data \
        .sort_values(['trip_id', 'time']) \
        .groupby('trip_id') \
        .agg({
            'stop_id': lambda x: list(x),
            '_temp_id': lambda x: list(x)
        }) \
        .rename(columns={
            'stop_id': 'stop_ids', 
        }) \
        .reset_index()

    # Add indexes
    trip_stops['stop_indexes'] = trip_stops['stop_ids'].apply(lambda x: list(range(len(x))))
    
    # Create a new DataFrame with stop_ids, temp_ids and their corresponding indexes
    exploded_trip_stops = pd.concat(
        [pd.DataFrame(
            {'trip_id': x['trip_id'], 'stop_id': x['stop_ids'], '_temp_id': x['_temp_id'], 'trip_index': list(range(len(x['stop_ids'])))}
        ) for i, x in trip_stops.iterrows()], ignore_index=True)
    
    # Merge with the original DataFrame (using the temporary unique identifier)
    result = new_data.merge(exploded_trip_stops, on=['trip_id', 'stop_id', '_temp_id'])

    # Remove the temporary unique identifier column
    result = result.drop(columns=['_temp_id'])

    return result

train_data = add_trip_index(train_data)
print(f"Number of entries: {train_data.shape[0]}")
train_data.sort_values(['trip_id', 'time']).head()
# Out:
# Number of entries: 5524471
#                 trip_id product_id line_text transport_type  stop_id  \
# 2  80:800693:3040:000_1      Train      IRE3            IRE  8503424
# 0  80:800693:3040:000_1      Train      IRE3            IRE  8500090
# 3  80:800693:3040:000_2      Train      IRE3            IRE  8503424
# 1  80:800693:3040:000_2      Train      IRE3            IRE  8500090
# 4  80:800693:3041:000_1      Train        RB             RB  8500090
#
#   arrival_time departure_time  mean_arrival_delay  mean_departure_delay  \
# 2     06:58:00       07:00:00          307.000000            252.146667
# 0     08:15:00           None          126.575342                   NaN
# 3     07:58:00       08:00:00          158.090278            114.597222
# 1     09:15:00           None           63.750000                   NaN
# 4         None       05:58:00                 NaN                   NaN
#
#    median_arrival_delay  ...  std_arrival_delay  std_departure_delay  \
# 2                 101.0  ...         644.312728           638.846885
# 0                   0.0  ...         437.328440                  NaN
# 3                  92.0  ...         356.211415           351.588390
# 1                   0.0  ...         341.497883                  NaN
# 4                   NaN  ...                NaN                  NaN
#
#    n_arrival_delay  n_departure_delay  n_cancelled  n_through_trip  \
# 2               75                 75            1               0
# 0               17                  0            2               0
# 3              142                144            4               0
# 1               22                  0            4               0
# 4                0                  0            2               0
#
#    n_additional_trip  n_entries      time trip_index
# 2                  0         76  06:58:00          0
# 0                  0         76  08:15:00          1
# 3                  0        148  07:58:00          0
# 1                  0        148  09:15:00          1
# 4                  0         80  05:58:00          0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Example S9

# %%
s9_data = train_data[train_data['line_text'] == 'S9']
print(f"There are {s9_data.shape[0]:,} S9 entries.")
s9_data.sort_values(['trip_id', 'time']).head()
# Out:
# There are 11,222 S9 entries.
#                 trip_id product_id line_text transport_type  stop_id  \
# 1975  85:11:14089:011_1      Train        S9              S  8501120
# 1976  85:11:14089:011_1      Train        S9              S  8504000
# 1978  85:11:14089:011_1      Train        S9              S  8504010
# 1979  85:11:14089:011_1      Train        S9              S  8504011
# 1980  85:11:14089:011_1      Train        S9              S  8504012
#
#      arrival_time departure_time  mean_arrival_delay  mean_departure_delay  \
# 1975         None       00:04:00                 NaN                32.375
# 1976     00:06:00       00:07:00              89.800                57.775
# 1978     00:09:00       00:09:00              55.750                76.200
# 1979     00:12:00       00:12:00             115.925               144.625
# 1980     00:16:00       00:16:00             102.325               132.925
#
#       median_arrival_delay  ...  std_arrival_delay  std_departure_delay  \
# 1975                   NaN  ...                NaN            36.022562
# 1976                  77.0  ...          41.465587            44.396516
# 1978                  49.0  ...          44.857467            48.447804
# 1979                 115.0  ...          51.286719            54.629140
# 1980                  97.0  ...          57.884229            60.299419
#
#       n_arrival_delay  n_departure_delay  n_cancelled  n_through_trip  \
# 1975                0                 40            0               0
# 1976               40                 40            0               0
# 1978               40                 40            0               0
# 1979               40                 40            0               0
# 1980               40                 40            0               0
#
#       n_additional_trip  n_entries      time trip_index
# 1975                 40         40  00:04:00          0
# 1976                 40         40  00:06:00          1
# 1978                 40         40  00:09:00          2
# 1979                 40         40  00:12:00          3
# 1980                 40         40  00:16:00          4
#
# [5 rows x 21 columns]

# %%
s9_data_stop_ids = s9_data['stop_id'].unique()
print(f"There are {len(s9_data_stop_ids):,} unique stop ids for the S9 line.")
# Out:
# There are 88 unique stop ids for the S9 line.

# %%
stops = pd.read_csv("../../data/processed/stops.csv")
s9_data = s9_data.merge(stops, on='stop_id')
s9_data_stop_names = s9_data['stop_name'].unique()
print(f"The stops for the S9 line are: {', '.join(s9_data_stop_names)}.")
# Out:
# The stops for the S9 line are: Lausanne, Pully-Nord, Moreillon, La Conversion, Grandvaux, Puidoux, Palézieux, Palézieux-Village, Châtillens, Ecublens-Rue, Moudon, Lucens, Granges-Marnand, Corcelles-Nord, Dompierre FR, Domdidier, Avenches, Faoug, Murten/Morat, Galmiz, Payerne, Muntelier-Löwenberg, Henniez, Kerzers, Sissach, Diepflingen, Sommerau, Rümlingen, Buckten, Läufelfingen, Trimbach, Olten, Zürich HB, Zürich Oerlikon, Zürich Hardbrücke, Glattbrugg, Rümlang, Oberglatt ZH, Niederglatt ZH, Bülach, Glattfelden, Eglisau, Hüntwangen-Wil, Rafz, Lottstetten, Jestetten, Neuhausen, Schaffhausen, Neuhausen Rheinfall, Zürich Stadelhofen, Uster, Nänikon-Greifensee, Schwerzenbach ZH, Dübendorf, Stettbach, Seon, Hallwil, Boniswil, Birrwil, Beinwil am See, Lenzburg, Waldibrücke, Ermensee, Emmenbrücke, Eschenbach LU, Ballwil, Hochdorf, Baldegg, Gelfingen, Hitzkirch, Emmenbrücke Gersag, Mosen, Hochdorf Schönau, Luzern, Baldegg Kloster, Wattwil, Lichtensteig, Dietfurt, Bütschwil, Lütisburg, Bazenheid, Wil SG, Bern, Bern Felsenau, Bern Tiefenau, Worblaufen, Steinibach, Unterzollikofen.

# %%
s9_data = s9_data.merge(stops, on='stop_id')
s9_data.sort_values(['trip_id', 'time']).head()
# Out:
#                trip_id product_id line_text transport_type  stop_id  \
# 0    85:11:14089:011_1      Train        S9              S  8501120
# 85   85:11:14089:011_1      Train        S9              S  8504000
# 103  85:11:14089:011_1      Train        S9              S  8504010
# 112  85:11:14089:011_1      Train        S9              S  8504011
# 121  85:11:14089:011_1      Train        S9              S  8504012
#
#     arrival_time departure_time  mean_arrival_delay  mean_departure_delay  \
# 0           None       00:04:00                 NaN                32.375
# 85      00:06:00       00:07:00              89.800                57.775
# 103     00:09:00       00:09:00              55.750                76.200
# 112     00:12:00       00:12:00             115.925               144.625
# 121     00:16:00       00:16:00             102.325               132.925
#
#      median_arrival_delay  ...  n_additional_trip  n_entries      time  \
# 0                     NaN  ...                 40         40  00:04:00
# 85                   77.0  ...                 40         40  00:06:00
# 103                  49.0  ...                 40         40  00:09:00
# 112                 115.0  ...                 40         40  00:12:00
# 121                  97.0  ...                 40         40  00:16:00
#
#      trip_index    stop_name_x  stop_lon_x  stop_lat_x    stop_name_y  \
# 0             0       Lausanne   2537875.0   1152042.0       Lausanne
# 85            1     Pully-Nord   2540090.0   1151785.0     Pully-Nord
# 103           2  La Conversion   2541649.0   1151592.0  La Conversion
# 112           3      Grandvaux   2545034.0   1149767.0      Grandvaux
# 121           4        Puidoux   2548335.0   1149392.0        Puidoux
#
#      stop_lon_y stop_lat_y
# 0     2537875.0  1152042.0
# 85    2540090.0  1151785.0
# 103   2541649.0  1151592.0
# 112   2545034.0  1149767.0
# 121   2548335.0  1149392.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Into Network

# %%
def create_network_representation(data):
    # Create a new DataFrame with columns trip_id, trip_index, stop_id, and n_entries
    network_data = data[['trip_id', 'trip_index', 'stop_id', 'n_entries']].copy()

    # Add a new column next_stop_id that contains the stop_id of the trip_index i+1 for each trip_id
    network_data['next_stop_id'] = network_data.groupby('trip_id')['stop_id'].shift(-1)

    # Remove rows with missing next_stop_id
    network_data = network_data.dropna(subset=['next_stop_id'])

    # Group by stop_id, next_stop_id, and sum up the n_entries for duplicate edges
    network_data = network_data.groupby(['stop_id', 'next_stop_id'])['n_entries'].sum().reset_index()

    return network_data

network_data = create_network_representation(train_data)
network_data.head()
# Out:
#    stop_id  next_stop_id  n_entries
# 0  8500010     8500016.0      11443
# 1  8500010     8500020.0      43662
# 2  8500010     8500021.0        522
# 3  8500010     8500023.0      31297
# 4  8500010     8500090.0      33589

# %%
# merge with stops
network_data = network_data \
    .merge(stops, left_on='stop_id', right_on='stop_id') \
    .rename(columns={
        'stop_id': 'source',
        'stop_name': 'source_name'
        }) \
    .merge(stops, left_on='next_stop_id', right_on='stop_id') \
    .rename(columns={
        'stop_id': 'target',
        'stop_name': 'target_name'
    }) \
    .rename(columns={
        'n_entries': 'weight'
    })[['source', 'source_name', 'target', 'target_name', 'weight']]
network_data.head()
# Out:
#     source source_name   target       target_name  weight
# 0  8500010   Basel SBB  8500016  Basel St. Johann   11443
# 1  8500010   Basel SBB  8500020           Muttenz   43662
# 2  8500010   Basel SBB  8500021          Pratteln     522
# 3  8500020     Muttenz  8500021          Pratteln   43361
# 4  8500010   Basel SBB  8500023           Liestal   31297

# %%
# Write in csv
network_data.to_csv("../../data/processed/network_edges.csv", index=False)

# %%
# create nodes
nodes_1 = network_data[['source', 'source_name']] \
    .drop_duplicates() \
    .rename(columns={
        'source': 'id',
        'source_name': 'label'
    })
nodes_2 = network_data[['target', 'target_name']] \
    .drop_duplicates() \
    .rename(columns={
        'target': 'id',
        'target_name': 'label'
    })
nodes = pd.concat([nodes_1, nodes_2]) \
    .drop_duplicates()
nodes.head()
# Out:
#          id                    label
# 0   8500010                Basel SBB
# 3   8500020                  Muttenz
# 6   8500022  Frenkendorf-Füllinsdorf
# 8   8500023                  Liestal
# 10  8500104                    Court

# %%
nodes.to_csv("../../data/processed/network_nodes.csv", index=False)
